# %%
import sys
print(sys.executable)
# Out:
# /home/nexahub/Desktop/Python3/agentic/bin/python

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("Everything works 🔥")
# Out:
# Everything works 🔥

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print(pd.__version__)
print(np.__version__)
# Out:
# 3.0.5
# 2.5.2

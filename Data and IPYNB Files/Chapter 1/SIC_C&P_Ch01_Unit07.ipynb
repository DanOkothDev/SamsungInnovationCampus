# %% [markdown]
# ## Mission

# %% [markdown]
# ### 2. Mission

# %%
import random

n = random. randint (1, 3) # randomly generates numbers among 1, 2, 3
if n == 1:
    computer_choice = "Left"
elif n == 2:
    computer_choice = "Middle"
else:
    computer_choice = "Right"

user_choice = input("Which side will you attack?(left, middle, right) : ")
if computer_choice == user_choice:
    print("Offense failed.")
else:
    print ("Congrats!! Offense succeeded.")
print('computer defense position :', computer_choice)
# Out:
# Which side will you attack?(left, middle, right) :  right
# Congrats!! Offense succeeded.
# computer defense position : Middle

# %% [markdown]
# ## Key concept

# %% [markdown]
# ### 1.1. else statement which is executed when the condition is false

# %%
score = 90
if score > 90:
    print('Accepted')
    print('Also receive a scholarship')
else:
    print('Not accepted.')
# Out:
# Not accepted.

# %% [markdown]
# ### 1.2. if statement without else statement

# %%
hour = 10
if hour < 12:
    print ('It is morning.')
if hour >= 12:
    print ('It is afternoon.')
# Out:
# It is morning.

# %% [markdown]
# ### 1.3. if-else statement

# %%
hour = 10
if hour < 12:
    print ('It is morning.')
else:
    print ('It is afternoon.')
# Out:
# It is morning.

# %% [markdown]
# ### 1.5. if-else statement to determine odd/even numbers

# %%
num = 10
if num % 2 == 0:
    print(num, 'is an even number.')
else:
    print(num, 'is an odd number.')
# Out:
# 10 is an even number.

# %% [markdown]
# ### 1.6. Writing if-else statement inside if-else statement

# %%
num = int(input("Enter an integer: "))
if num >= 0:        # make sure to indent the block
    if num == 0:    # check specific conditions inside the block
        print("It is 0.")
    else:
        print("It is positive.")
else:
    print ("It is negative.")
# Out:
# Enter an integer:  -20
# It is negative.

# %% [markdown]
# ### 1.7. Using nested if-else statement to discriminate even/odd numbers

# %%
num = 100
if num < 0:
    print (num, 'is negative.')
else:
    print (num, 'is not negative.')
    if num % 2 == 0:
        print(num, 'is an even number.')
    else:
        print (num, 'is an odd number.')
# Out:
# 100 is not negative.
# 100 is an even number.

# %% [markdown]
# ### 1.8. Flow control in various cases

# %%
num = -100
if num < 0:
    print (num, 'is negative.')
else:
    print (num, 'is not negative.')
    if num % 2 == 0:
        print(num, 'is an even number.')
    else:
        print (num, 'is an odd number.')
# Out:
# -100 is negative.

# %% [markdown]
# ### 2.2. Code example that prints positive, negative, and 0 after receiving integer as an input

# %%
num = int(input("Enter an integer: "))
if num > 0:
    print("It is positive.")
elif num == 0:
    print("It is 0.")
else:
    print("It is negative.")
# Out:
# Enter an integer:  6
# It is positive.

# %%
num = int(input("Enter an integer: "))
if num > 0:
    print("It is positive.")
elif num == 0:
    print("It is 0.")
else:
    print("It is negative.")
# Out:
# Enter an integer:  -5
# It is negative.

# %%
num = int(input("Enter an integer: "))
if num > 0:
    print("It is positive.")
elif num == 0:
    print("It is 0.")
else:
    print("It is negative.")
# Out:
# Enter an integer:  6
# It is positive.

# %% [markdown]
# ### 2.4. Grade Generator example A: Code using multiple if statements

# %%
score = int (input ('Enter score : '))
if score >= 90:                # If 90 or above, 'A'
    grade = 'д'
if score < 90 and score >= 80: # If under 90, 80 or above, 'B'
    grade = 'B'
if score < 80 and score >= 70: # If under 80, 70 or above,'C'
    grade = 'C'
if score < 70 and score >= 60: # If under 70, 60 or above, 'D'
    grade = 'D'
if score < 60:                 #If under 60, 'F'
    grade = 'F'
print ('Your grade is: ', grade)
# Out:
# Enter score :  88
# Your grade is:  B

# %% [markdown]
# ### 2.5. Grade generator example B: Grade generator code using if-else statement

# %%
score = int(input ('Enter score : '))
if score >= 90:                # If 90 or above, 'A'
    grade = 'A'
else:
    if score >= 80:            # If under 90, 80 or above, 'B'
        grade = 'B'
    else:
        if score >= 70:        # If under 80, 70 or above, 'C'
            grade = 'c'
        else:
            if score >= 60:   # If under 70, 60 or above, 'D'
                grade = 'D'
            else:
                grade = 'F'   #If under 60, 'F'

print('Your grade is: ', grade)
# Out:
# Enter score :  88
# Your grade is:  B

# %% [markdown]
# ### 2.8. Grade generator example C: Grade generator code using if-elif-else statement

# %%
score = int(input('Enter score : '))
if score >= 90:      # If 90 or above, 'A'
    grade = 'A'
elif score >= 80:    # If not 'A', 'B' if 80 or above
    grade = 'B'
elif score >= 70:    # If not 'B', 'C' if 70 or above
    grade = 'C'
elif score >= 60:    # If not 'C', 'D' if 60 or above
    grade = 'D'
else:                # Otherwise, 'F'
    grade = 'F'
print('Your grade is: ', grade)
# Out:
# Enter score :  88
# Your grade is:  B

# %% [markdown]
# ### 2.10. Example of a complex conditional expression

# %%
a = 10
b = 14                # if b is changed to 13, it does not meet the first conditional statement
if (a % 2 == 0) and (b % 2 == 0):    # first conditional statement
    print('Both are even.')
if (a % 2 == 0) or (b % 2 == 0):     # second conditional statement
    print('At least one is even.')
# Out:
# Both are even.
# At least one is even.

# %%
a = 10
b = 13                # if b is changed to 13, it does not meet the first conditional statement
if (a % 2 == 0) and (b % 2 == 0):    # first conditional statement
    print('Both are even.')
if (a % 2 == 0) or (b % 2 == 0):     # second conditional statement
    print('At least one is even.')
# Out:
# At least one is even.

# %%
year = int(input('Enter the year: '))
is_leap_year = ((year % 4 == 0) and (year % 100 != 0) or (year % 400 == 0))
print (year, 'is a leap year?', is_leap_year)
# Out:
# Enter the year:  2025
# 2025 is a leap year? False

# %% [markdown]
# ### 3. Application production practice

# %%
print('#' * 50)
print("This is David's fruit shop.")
print('1: Apple( price: 5000 won)')
print('2: Grape( price: 6000 won)')
print('3: Melon( price : 8000 won)')
print('4: Orange( price : 2000 won)')
print('#' * 50)

total_price = 0
order = int(input(('Enter item number (between 1~4) >> ')))
count = int(input(('Enter number of items (between 1~10) >> ')))

if order == 1:
    fruit = 'Apple'
    price = 5000
elif order == 2:
    fruit = 'Grape'
    price = 6000
elif order == 3:
    fruit = 'Melon'
    price = 8000
else:
    fruit = 'Orange'
    price = 2000

print('Fruit selected :', fruit)
print('Price.:', price)
print('Quantity :', count)
print('Total price is', price * count, 'won.')

money = int(input('Insert money please(ex: 15000) >>>'))
if money < price * count :
    print('Not enough money.')
else:
    change = money - price * count
    print(money, 'won received. Your change is', change, 'won.')
# Out:
# ##################################################
# This is David's fruit shop.
# 1: Apple( price: 5000 won)
# 2: Grape( price: 6000 won)
# 3: Melon( price : 8000 won)
# 4: Orange( price : 2000 won)
# ##################################################
# Enter item number (between 1~4) >>  2
# Enter number of items (between 1~10) >>  2
# Fruit selected : Grape
# Price.: 6000
# Quantity : 2
# Total price is 12000 won.
# Insert money please(ex: 15000) >>> 20000
# 20000 won received. Your change is 8000 won.

# %% [markdown]
# ## Let’s code

# %% [markdown]
# ### 1.2. The program resolution code for ID verification

# %%
d = "ilovepython"
s = input("Enter the ID: ")
if s == d:
    print("Welcome.")
else:
    print ("ID not found.")
# Out:
# Enter the ID:  ilovepython
# Welcome.

# %% [markdown]
# ### 1.3. Program to verify ID and password

# %%
my_id = "ilovepython"
password = "mypass1234"
string1 = input("Enter ID: ")
strinq2 = input("Enter Password: ")
if string1 == my_id and strinq2 == password:
    print("Welcome.")
elif string1 != my_id:
    print ("ID not found.")
else:
    print("The password is wrong.")
# Out:
# Enter ID:  ilovepython
# Enter Password:  mypass1234
# Welcome.

# %% [markdown]
# ### 2.1. Code example of random number generation

# %%
import random        # call the random module

number = random.randint(1, 100)
print(number)
# Out:
# 87

# %% [markdown]
# ### 2.2. Coin tossing game using a random function

# %%
import random

number = random.randrange(2)
print (number)
# Out:
# 0

# %%
import random

print("Start coin tossing game. ")
coin = random. randrange (2)
if coin == 0:
    print("Front.")
else:
    print ("Back.")
print("Game finished.")
# Out:
# Start coin tossing game.
# Front.
# Game finished.

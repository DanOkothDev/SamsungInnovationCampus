# %% [markdown]
# ## Mission

# %% [markdown]
# ### 3. Mission

# %%
tele_dir_dic = {'Chinese restaurant': ('010-1234-4500'), 'Japanese restaurant': ('010-2230-6540'), 'Italian restaurant':('010-3232-7788')}
print("previous number")
for key, value in tele_dir_dic.items():
    print(key + " :", value)
for key, value in tele_dir_dic.items():
    adr, review = input(key+ 'Please write address and review of: ').split()
    update = (value, adr, review)
    tele_dir_dic[key] = update
print("Updated number")
for key, value in tele_dir_dic.items():
    print(key + " :", value)
# Out:
# previous number
# Chinese restaurant : 010-1234-4500
# Japanese restaurant : 010-2230-6540
# Italian restaurant : 010-3232-7788
# Chinese restaurantPlease write address and review of:  Northern_Busan It_was_ok
# Japanese restaurantPlease write address and review of:  Sasang_Busan It_was_delicious
# Italian restaurantPlease write address and review of:  Donglae_Busan Very_delicious
# Updated number
# Chinese restaurant : ('010-1234-4500', 'Northern_Busan', 'It_was_ok')
# Japanese restaurant : ('010-2230-6540', 'Sasang_Busan', 'It_was_delicious')
# Italian restaurant : ('010-3232-7788', 'Donglae_Busan', 'Very_delicious')

# %% [markdown]
# ## Key concept

# %% [markdown]
# ### 1. Converting List and Tuple to Dictionary

# %%
keys = ['a', 'b', 'c', 'd']
x = dict.fromkeys(keys)
x
# Out:
# {'a': None, 'b': None, 'c': None, 'd': None}

# %%
keys = ('a', 'b', 'c', 'd')
x = dict.fromkeys(keys)
x
# Out:
# {'a': None, 'b': None, 'c': None, 'd': None}

# %%
y = dict.fromkeys(keys, 100)
y
# Out:
# {'a': 100, 'b': 100, 'c': 100, 'd': 100}

# %%
x = {'a': 0, 'b': 0, 'c': 0, 'd': 0}
x['z']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 2
#       1 x = {'a': 0, 'b': 0, 'c': 0, 'd': 0}
# ----> 2 x['z']
#
# KeyError: 'z'

# %%
from collections import defaultdict # bring defaultdic from collections module
keys = ('a', 'b', 'c', 'd')
y = dict.fromkeys(keys, 100)
y = defaultdict(int)    # set default value as int

# %%
y['z']
# Out:
# 0

# %%
y
# Out:
# defaultdict(int, {'z': 0})

# %%
int()
# Out:
# 0

# %%
from collections import defaultdict
keys = ('a', 'b', 'c', 'd')
y = dict.fromkeys (keys, 100)
y = defaultdict(int, y) # int as set default value
y['z']
# Out:
# 0

# %%
from collections import defaultdict

word = 'abcbaabca'
counter = defaultdict(int)
for letter in word:
    counter[letter] += 1

counter
# Out:
# defaultdict(int, {'a': 4, 'b': 3, 'c': 2})

# %% [markdown]
# ### 2. Print Dictionary Using Loop Statements

# %%
int()
# Out:
# 0

# %%
list_dict = defaultdict(list)
list_dict
# Out:
# defaultdict(list, {})

# %%
list_dict['listl']
# Out:
# []

# %%
x = {'a': 10, 'b': 20, 'c': 30, 'd': 40}
for i in x:
    print(i, end=' ')
# Out:
# a b c d

# %%
x = {'a': 10, 'b': 20, 'c': 30, 'd': 40}
for key, value in x.items():
    print(key, value)
# Out:
# a 10
# b 20
# c 30
# d 40

# %%
x = {'a': 10, 'b': 20, 'c': 30, 'd': 40}
for key in x.keys():
    print(key, end=' ')
# Out:
# a b c d

# %%
x = {'a': 10, 'b': 20, 'c': 30, 'd': 40}
for value in x.values():
    print(value, end=' ')
# Out:
# 10 20 30 40

# %% [markdown]
# ### 3. Dictionary in Dictionary

# %%
terrestrial_planet = {
    'Mercury': {
        'mean_radius': 2439.7,
        'mass': 3.3022E+23,
        'orbital_period': 87.969
    },
    'Venus': {
        'mean_radius': 6051.8,
        'mass': 4.8676E+24,
        'orbital_period': 224.70069,
    },
    'Earth': {
        'mean radius': 6371.0,
        'mass': 5.97219E+24,
        'orbital_period': 365.25641,
    },
    'Mars': {
        'mean_radius': 3389.5,
        'mass': 6.4185E+23,
        'orbital_period': 686.9600,
    }
}
print(terrestrial_planet ['Venus']['mean_radius'])
# Out:
# 6051.8

# %% [markdown]
# ### 4. Assignment and Copying of Double dictionaries

# %%
x = {'a': 0, 'b': 0, 'c': 0, 'd': 0}
y = x

# %%
x is y
# Out:
# True

# %%
y['a'] = 99

# %%
y
# Out:
# {'a': 99, 'b': 0, 'c': 0, 'd': 0}

# %%
x
# Out:
# {'a': 99, 'b': 0, 'c': 0, 'd': 0}

# %%
x = {'a': 0, 'b': 0, 'c': 0, 'd': 0}

# %%
y = x.copy()

# %%
x is y
# Out:
# False

# %%
x == y
# Out:
# True

# %%
x = {'a': 0, 'b': 0, 'c': 0, 'd': 0}

# %%
y = x.copy()
y['a'] = 99

# %%
x is y
# Out:
# False

# %%
x == y
# Out:
# False

# %%
x = {'a': {'python': '2.7'}, 'b': {'python': '3.6'}}
y = x.copy()

# %%
y['a']['python'] = '2.7.15'
x
# Out:
# {'a': {'python': '2.7.15'}, 'b': {'python': '3.6'}}

# %%
y
# Out:
# {'a': {'python': '2.7.15'}, 'b': {'python': '3.6'}}

# %%
x = {'a': {'python': '2.7'}, 'b': {'python': '3.6'}}
import copy             # call copy module
y = copy.deepcopy(x)    # deep copy using deepcopy function
y['a']['python'] = '2.7.15'
x
# Out:
# {'a': {'python': '2.7'}, 'b': {'python': '3.6'}}

# %%
y
# Out:
# {'a': {'python': '2.7.15'}, 'b': {'python': '3.6'}}

# %% [markdown]
# ## Let’s code

# %% [markdown]
# ### 1. Repeat using dictionary methods

# %%
phone_book = {"David Doe": "010-1234-5678", "John Smith": "010-1234-5679", "Jane Carter": "010-1234-5680"}

# %%
phone_book.items()
# Out:
# dict_items([('David Doe', '010-1234-5678'), ('John Smith', '010-1234-5679'), ('Jane Carter', '010-1234-5680')])

# %%
phone_book.keys()
# Out:
# dict_keys(['David Doe', 'John Smith', 'Jane Carter'])

# %%
phone_book.values()
# Out:
# dict_values(['010-1234-5678', '010-1234-5679', '010-1234-5680'])

# %%
phone_book.items()
# Out:
# dict_items([('David Doe', '010-1234-5678'), ('John Smith', '010-1234-5679'), ('Jane Carter', '010-1234-5680')])

# %%
for name, phone_num in phone_book.items():
    print (name, ':', phone_num)
# Out:
# David Doe : 010-1234-5678
# John Smith : 010-1234-5679
# Jane Carter : 010-1234-5680

# %% [markdown]
# ### 2. Module Definition and Import Statement

# %%
import datetime        # The following sentence is omitted
datetime.datetime.now()
# Out:
# datetime.datetime(2025, 12, 2, 11, 54, 3, 689574)

# %%
today = datetime.date.today()
print(today)
# Out:
# 2025-12-02

# %%
today
# Out:
# datetime.date(2025, 12, 2)

# %%
today.year
# Out:
# 2025

# %%
today.month
# Out:
# 12

# %%
today.day
# Out:
# 2

# %%
print(dir(datetime))
# Out:
# ['MAXYEAR', 'MINYEAR', 'UTC', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'date', 'datetime', 'datetime_CAPI', 'time', 'timedelta', 'timezone', 'tzinfo']

# %%
start_time = datetime.datetime.now()
start_time.replace(month = 12, day = 25)
# Out:
# datetime.datetime(2025, 12, 25, 11, 58, 39, 732570)

# %%
import datetime as dt        # use dt instead of datetime from now on
start_time = dt.datetime.now()
start_time.replace(month = 12, day = 25)
# Out:
# datetime.datetime(2025, 12, 25, 11, 58, 52, 821465)

# %%
from datetime import datetime
start_time = datetime.now()
start_time.replace(month = 12, day = 25)
# Out:
# datetime.datetime(2025, 12, 25, 11, 58, 53, 417829)

# %%
from datetime import *
today = date.today()
today
# Out:
# datetime.date(2025, 12, 2)

# %%
import time
seconds = time.time()
print('Time after epoxy = ', seconds)
# Out:
# Time after epoxy =  1764644810.4611309

# %%
import time
unix_timestamp = time.time()
local_time = time.localtime(unix_timestamp)
local_time
# Out:
# time.struct_time(tm_year=2025, tm_mon=12, tm_mday=2, tm_hour=12, tm_min=7, tm_sec=9, tm_wday=1, tm_yday=336, tm_isdst=0)

# %%
import time
unix_timestamp = time.time()
local_time = time.localtime(unix_timestamp)
print(time.strftime('%Y-%m-%d %H:%M:%S', local_time))
# Out:
# 2025-12-02 12:07:20

# %%
import math
print(dir(math))    # returns built-in functions of the math module
# Out:
# ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'cbrt', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exp', 'exp2', 'expm1', 'fabs', 'factorial', 'floor', 'fma', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'lcm', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'nextafter', 'perm', 'pi', 'pow', 'prod', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'sumprod', 'tan', 'tanh', 'tau', 'trunc', 'ulp']

# %%
import math as m
m.pow (3, 3) # 3 to 3 squares
# Out:
# 27.0

# %%
m.fabs(-99) # The absolute value of -99
# Out:
# 99.0

# %%
m.ceil(2.1) #2.1 rounded up
# Out:
# 3

# %%
m.ceil(-2.1) #-2.1 rounded up
# Out:
# -2

# %%
m.floor(2.1) # 2.1 rounded down
# Out:
# 2

# %%
m.log(2.71828)
# Out:
# 0.999999327347282

# %%
m.log(100, 10) # value of 100 with logarithm 10 as the bottom
# Out:
# 2.0

# %%
import math as m

m.sin(0.0)        # value of sin 0
# Out:
# 0.0

# %%
m.sin(90.0)       # do not use general angle of 90.0
# Out:
# 0.8939966636005579

# %%
m.sin(m.pi/2)     # radian notation
# Out:
# 1.0

# %% [markdown]
# ## Mission

# %% [markdown]
# ### 2. Mission

# %%
menu = {'Americano': 3000, 'Ice Americano': 3500, 'Cappuccino' : 4000, 'Cafe Latte':4500, 'Espresso': 3600 }
for key in menu:
    print(f"{key:16s} price : {menu[key]:,}KRW")
# Out:
# Americano        price : 3,000KRW
# Ice Americano    price : 3,500KRW
# Cappuccino       price : 4,000KRW
# Cafe Latte       price : 4,500KRW
# Espresso         price : 3,600KRW

# %%
print('Americano       Price: 3,000 KRW')
print('Ice Americano   Price: 3,500 KRW')
print('Cappuccino      Price: 4,000 KRW')
print('Cafe Latte      Price: 4,500 KRW')
print('Espresso        Price: 3,600 KRW')
choice = input('Select one menu from the list: ')
if choice in menu.keys():
    print(f"{choice} is {menu[choice]:,} KRW. Please make a payment.")
else:
    print(f"Sorry. {choice} is not in the menu.")
# Out:
# Americano       Price: 3,000 KRW
# Ice Americano   Price: 3,500 KRW
# Cappuccino      Price: 4,000 KRW
# Cafe Latte      Price: 4,500 KRW
# Espresso        Price: 3,600 KRW
# Select one menu from the list:  Cafe Latte
# Cafe Latte is 4,500 KRW. Please make a payment.

# %%
menu = {'Americano': 3000, 'Ice Americano': 3500, 'Cappuccino': 4000, 'Cafe Latte':4500, 'Espresso':3600 }
for key in menu:
    print(f"{key:16s} price : {menu[key]:,}KRW")
# Out:
# Americano        price : 3,000KRW
# Ice Americano    price : 3,500KRW
# Cappuccino       price : 4,000KRW
# Cafe Latte       price : 4,500KRW
# Espresso         price : 3,600KRW

# %%
print('Americano        Price : 3,000 KRW')
print('Ice Americano    Price : 3,500 KRW')
print('Cappuccino       Price : 4,000 KRW')
print('Cafe Latte       Price : 4,500 KRW')
print('Espresso         Price : 3,600 KRW')
choice = input('Select one menu from the list: ')
if choice in menu.keys():
    print(f"{choice} is {menu[choice]:,} KRW. Please make a payment.")
else:
    print(f"Sorry. {choice} is not in the menu.")
# Out:
# Americano        Price : 3,000 KRW
# Ice Americano    Price : 3,500 KRW
# Cappuccino       Price : 4,000 KRW
# Cafe Latte       Price : 4,500 KRW
# Espresso         Price : 3,600 KRW
# Select one menu from the list:  Cafe Latte
# Cafe Latte is 4,500 KRW. Please make a payment.

# %% [markdown]
# ## Key concept

# %% [markdown]
# ### 2. Key-Value Pair of Dictionary

# %%
person = {'Name': 'David Doe', 'Age': 26, 'Weight': 82}

# %%
person['Name']
# Out:
# 'David Doe'

# %%
person['Age']
# Out:
# 26

# %%
person['Weight']
# Out:
# 82

# %%
students = { 2019001: 'John Smith', 2019002: 'Jane Carter', 2019003: 'Peter Kelly'}
students[2019001]
# Out:
# 'John Smith'

# %%
students[2019002]
# Out:
# 'Jane Carter'

# %%
students[2019003]
# Out:
# 'Peter Kelly'

# %% [markdown]
# ### 3. Key Approach and Value Assignment of Dictionary

# %%
person = {'Name' : 'David Doe', 'Age' : 26, 'Weight' : 82 }

# %%
person['Job'] = 'Data Scientist' # New key:insert the item of the value

# %%
person
# Out:
# {'Name': 'David Doe', 'Age': 26, 'Weight': 82, 'Job': 'Data Scientist'}

# %%
person = {'Name' : 'David Doe', 'Age': 26, 'Weight' : 82 }

# %%
person['Age'] = 27

# %%
person
# Out:
# {'Name': 'David Doe', 'Age': 27, 'Weight': 82}

# %%
person = {'Name' : 'David Doe', 'Age' : 26, 'Weight' : 82 }

# %%
del person['Age']

# %%
person
# Out:
# {'Name': 'David Doe', 'Weight': 82}

# %%
person = {'Name' : 'David Doe', 'Age' : 26, 'Weight' : 82 }

# %%
del person ['Hometown']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 del person ['Hometown']
#
# KeyError: 'Hometown'

# %%
person = {'Name' : 'David Doe', 'Age' : 26, 'Weight' : 82 }

# %%
len(person) # Returns the number of items in dictionary
# Out:
# 3

# %%
'Name' in person # 'Name' is found in the key
# Out:
# True

# %%
'Job' in person # 'Job' is not found in the key
# Out:
# False

# %%
'David Doe' in person # 'David Doe' is found in the value but not in the key (caution)
# Out:
# False

# %%
'David Doe' not in person # Returns True because 'David Doe' is not found in the key
# Out:
# True

# %%
d1 = {'Name' : 'David Doe', 'Age' : 26 }

# %%
d2 = {'Age' : 26, 'Name' : 'David Doe' }

# %%
d1 == d2
# Out:
# True

# %%
d1 != d2
# Out:
# False

# %%
d1 > d2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 d1 > d2
#
# TypeError: '>' not supported between instances of 'dict' and 'dict'

# %% [markdown]
# ### 4. json Data Dictionary / List Conversion

# %%
import json

data = '{"Name": "David Doe", "Age": 25, "Hobby": ["basketball"],\
"Family": {"father": "John Doe", "mother": "Marry Doe"}, "Married": true}'

json_data = json.loads(data)

print(type(json_data))
print(json_data['Name'])
print(json_data['Family'])
print(json_data['Married'])
# Out:
# <class 'dict'>
# David Doe
# {'father': 'John Doe', 'mother': 'Marry Doe'}
# True

# %%
import json

data = '{"title": "The Old man and The Sea", "ISBN": "12345", "Author" : "Ernest Hemingway"}'
json_data = json.loads(data)

print(type(json_data))
print(json_data['title'])
print(json_data['ISBN'])
print(json_data['Author'])
# Out:
# <class 'dict'>
# The Old man and The Sea
# 12345
# Ernest Hemingway

# %%
import json

data = '{"title": "The Old man and The Sea", "ISBN": "12345", "Author": "Ernest Hemingway"}'
json_data = json.loads(data)

# Code to create son data as book.json file
with open('book.json', 'w') as f:
    json.dump(json_data, f, indent='\t')

# %% [markdown]
# ## Let’s code

# %% [markdown]
# ### 1. Dictionary

# %%
phone_book = { } # Create an empty dictionary

# %%
phone_book["David"] = "010-1234-5678"

# %%
print(phone_book)
# Out:
# {'David': '010-1234-5678'}

# %%
phone_book = {"David": "010-1234-5678"}

# %%
phone_book["John"] = "010-1234-5679"
phone_book["Daniel"] = "010-1234-5680"
print(phone_book)
# Out:
# {'David': '010-1234-5678', 'John': '010-1234-5679', 'Daniel': '010-1234-5680'}

# %% [markdown]
# ### 2. Comparison of the list and dictionary

# %%
lst = [11, 22, 33, 44, 55]
print('before pop(0) :', lst)
print('before pop(0) lst[1] = ', lst[1])
lst.pop (0)     # Use index 0 to delete the first item of the list
print('after pop(0) :', lst)
print('after pop(0) lst[1] = ', lst[1])    # The value referred by lst[1] changes
# Out:
# before pop(0) : [11, 22, 33, 44, 55]
# before pop(0) lst[1] =  22
# after pop(0) : [22, 33, 44, 55]
# after pop(0) lst[1] =  33

# %%
dic = {0:11, 1:22, 2:33, 3:44, 4:55}
# Print the items() function that returns the tuple pair (key-value) of dictionary
print('before pop(0) :', dic.items())
print('before pop(0) dic[1] = ', dic[1])
dic.pop (0)     # Items (0, 11) are deleted with the key O
print('after pop(0) :', dic.items())
print('after pop(0) dic[1] = ', dic[1])    # The value referred by dic[1] does not change
# Out:
# before pop(0) : dict_items([(0, 11), (1, 22), (2, 33), (3, 44), (4, 55)])
# before pop(0) dic[1] =  22
# after pop(0) : dict_items([(1, 22), (2, 33), (3, 44), (4, 55)])
# after pop(0) dic[1] =  22

# %%
lst.clear()
lst
# Out:
# []

# %% [markdown]
# ### 3. Formatting for better print (Using format)

# %%
'{} Python!'.format('Hello')
# Out:
# 'Hello Python!'

# %%
'I Like {} and {}'.format('Python', 'Java')
# Out:
# 'I Like Python and Java'

# %%
'I like {0} and {1}'. format('Python', 'Java')
# Out:
# 'I like Python and Java'

# %%
'I like {1} and {0}'. format ('Python', 'Java')
# Out:
# 'I like Java and Python'

# %%
'I like {0}, {0}, {0}'.format ('Python', 'Java')
# Out:
# 'I like Python, Python, Python'

# %%
print('12345678901234567890')
print('{0:4d},{0:5d},{0:6d}'.format(123))
# Out:
# 12345678901234567890
#  123,  123,   123

# %%
'Precision of two decimal places: {0:.2f}. Precision of three decimal places {0:.3f}'.format(1/3)
# Out:
# 'Precision of two decimal places: 0.33. Precision of three decimal places 0.333'

# %%
'Real numbers for 10 spaces : {0:10.3f}, {0:10.4f}'.format(3.1415926)
# Out:
# 'Real numbers for 10 spaces :      3.142,     3.1416'

# %%
for i in range(2, 11, 2):
    print('{0:3d} {1:4d} {2:5d}'.format(i, i*i, i*i*i))
# Out:
#   2    4     8
#   4   16    64
#   6   36   216
#   8   64   512
#  10  100  1000

# %% [markdown]
# ### 4. Formatting for better print (Using f-string)

# %%
text = "Hello"
print(f"{text} Python!")
# Out:
# Hello Python!

# %%
lang1 = "Python"
lang2 = "Java"
print(f"I Like {lang1} and {lang2}")
# Out:
# I Like Python and Java

# %%
a = "Java"
b = "Python"
print(f"I like {a} and {b}")
# Out:
# I like Java and Python

# %%
a = "Java"
b = "Python"
print(f"I like {b} and {a}")
# Out:
# I like Python and Java

# %%
x = "Python"
print(f"I like {x}, {x}, {x}")
# Out:
# I like Python, Python, Python

# %%
num = 123
print("1234567890")
print(f"{num:4d}")
print("1234567890")
print(f"{num:5d}")
print("1234567890")
print(f"{num:6d}")
# Out:
# 1234567890
#  123
# 1234567890
#   123
# 1234567890
#    123

# %%
value = 1 / 3
print(f"Precision of two decimal places: {value:.2f}. "
      f"Precision of three decimal places: {value:.3f}")
# Out:
# Precision of two decimal places: 0.33. Precision of three decimal places: 0.333

# %%
num = 3.1415926
print(f"Real numbers for 10 spaces: {num:10.3f}, {num:10.4f}")
# Out:
# Real numbers for 10 spaces:      3.142,     3.1416

# %%
print("Output Alignment: 3d / 4d / 5d")
print("123 1234 12345")
print("-"*14)
for i in range(2, 11, 2):
    print(f"{i:3d} {i+1:4d} {i*i*i:5d}")
# Out:
# Output Alignment: 3d / 4d / 5d
# 123 1234 12345
# --------------
#   2    3     8
#   4    5    64
#   6    7   216
#   8    9   512
#  10   11  1000

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


students_data = pd.read_csv("./data/student/student-mat.csv", sep=";")
students_data.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [5 rows x 33 columns]

# %%
students_data.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
students_data.isnull().count()
# Out:
# school        395
# sex           395
# age           395
# address       395
# famsize       395
# Pstatus       395
# Medu          395
# Fedu          395
# Mjob          395
# Fjob          395
# reason        395
# guardian      395
# traveltime    395
# studytime     395
# failures      395
# schoolsup     395
# famsup        395
# paid          395
# activities    395
# nursery       395
# higher        395
# internet      395
# romantic      395
# famrel        395
# freetime      395
# goout         395
# Dalc          395
# Walc          395
# health        395
# absences      395
# G1            395
# G2            395
# G3            395
# dtype: int64

# %%
plt.hist(students_data['failures'])
plt.xlabel("Failures")
plt.ylabel("Count")
plt.title("Distribution of failures")
plt.grid(True)
# Out:
# np.int64(395)

# %%
sum(students_data['failures'] == 3)
# Out:
# 16

# %%
from math import *

sqrt(students_data['failures'].var())
# Out:
# 0.7436509736062507

# %%
print(students_data['failures'].std())
# Out:
# 0.7436509736062507

# %%
plt.hist(students_data['studytime'])
plt.xlabel("Study Time")
plt.ylabel("Count")
plt.title("Distribution of Study Time")
# Out:
# Text(0.5, 1.0, 'Distribution of Study Time')

# %%
sum(students_data['studytime']== 1)
# Out:
# 105

# %%
students_data['studytime'].mode()
# Out:
# 0    2
# Name: studytime, dtype: int64

# %%
students_data.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
plt.boxplot(students_data['G1'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7bc09fdbc050>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7bc09fdbc7d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7bc09fea2990>],
#  'medians': [<matplotlib.lines.Line2D at 0x7bc09fdbc550>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7bc09fdbc410>],
#  'means': []}

# %%
g2 = students_data['G2'].quantile()
g1 = students_data['G1'].quantile()

print(g1, g2)
# Out:
# 11.0 11.0

# %%
students_data['G1'].median()
students_data.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
plt.boxplot(students_data['absences'])
students_data['absences'].describe()
# Out:
# count    395.000000
# mean       5.708861
# std        8.003096
# min        0.000000
# 25%        0.000000
# 50%        4.000000
# 75%        8.000000
# max       75.000000
# Name: absences, dtype: float64

# %%
plt.boxplot([students_data['G1'], students_data['G2'], students_data['G3']], labels=['G1', 'G2', 'G3'])
plt.xlabel('Grades')
plt.ylabel('Values')
plt.title('Boxplots of Grades')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 plt.boxplot([students_data['G1'], students_data['G2'], students_data['G3']], labels=['G1', 'G2', 'G3'])
#       2 plt.xlabel('Grades')
#       3 plt.ylabel('Values')
#       4 plt.title('Boxplots of Grades')
#
# File ~/miniconda3/envs/agentic/lib/python3.13/site-packages/matplotlib/_api/deprecation.py:477, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     471 if len(args) > name_idx:
#     472     warn_deprecated(
#     473         since, message="Passing the %(name)s %(obj_type)s "
#     474         "positionally is deprecated since Matplotlib %(since)s; the "
#     475         "parameter will become keyword-only in %(removal)s.",
#     476         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 477 return func(*args, **kwargs)
#
# ...

# %%
data = [86, 87, 89]
data1 = [80, 70, 60]

d = pd.DataFrame(data, columns=['Marks'])
d1 = pd.DataFrame(data1, columns=['Marks'])

print(d.mean())
print(d1.mean())
print(d.std())
print(d1.std())
# Out:
# Marks    87.333333
# dtype: float64
# Marks    70.0
# dtype: float64
# Marks    1.527525
# dtype: float64
# Marks    10.0
# dtype: float64

# %%
import random
import time

def roll_dice(n):
    dice = []

    for i in range(n):
        dice.append(random.randint(1, 6))

    return dice

def find_winner(sdice_list, udice_list):
    computer_total = sum(udice_list)
    user_total = sum(sdice_list)

    print(f"Computer total is: {computer_total}")
    print(f"User total: {user_total}")

    if user_total > computer_total:
        print("User won!!")
    elif computer_total > user_total:
        print("Computer won!!")
    else:
        print("Its a tie!!")


def roll_again(choices, dice_list):
    print("Rolling again.......")
    time.sleep(3)

    for i in range(len(choices)):
        if choices[i] == "r":
            dice_list[i] = random.randint(1, 6)

    time.sleep(3)

def computer_strategy1(n):
    print("Computer is thinking....")
    time.sleep(3)

    choices = ''
    for i in range(n):
        choices = choices + "r"

    return choices

def computer_strategy2(n):
    print("Computer is thinking...")
    time.sleep(3)
    choices = ''

    for i in range(n):
        if computer_rolls[i] < 5:
            choices = choices + "r"

        else:
            choices = choices + "-"

    return choices

number_dice = int(input("Enter number of dice: "))
ready = input("Ready to start? Hit any key to continue")

user_rolls = roll_dice(number_dice)
print(f"User first roll: {user_rolls}")

user_choices = input("Enter - to hold or r to roll again: ")

while len(user_choices) != number_dice:
    print(f"You must enter {number_dice} choices")

    user_choices = input("Enter - to hold or r to roll again: ")

roll_again(user_choices, user_rolls)

print(f"Player new Roll, {user_rolls}")

print("Computer turn")
computer_rolls = roll_dice(number_dice)
print(f"Computer first Roll, {computer_rolls}")

computer_choices = computer_strategy2(number_dice)
print(f"Computer choice: {computer_choices}")

roll_again(computer_choices, computer_rolls)
print(f"Computer new Roll, {computer_rolls}")

find_winner(computer_rolls, user_rolls)
# Out:
# User first roll: [6, 4, 1, 1, 5, 2]
# Rolling again.......
# Player new Roll, [6, 4, 1, 4, 5, 3]
# Computer turn
# Computer first Roll, [5, 5, 4, 3, 3, 4]
# Computer is thinking...
# Computer choice: --rrrr
# Rolling again.......
# Computer new Roll, [5, 5, 3, 2, 4, 6]
# Computer total is: 23
# User total: 25
# User won!!

# %%
import turtle

colors = ['red', 'yellow', 'blue', 'orange', 'green', 'red']

aiden = turtle.Turtle()
turtle.bgcolor('black')

for n in range(36):
    aiden.color(colors[n % len(colors)])
    aiden.forward(100)
    aiden.left(60)
    aiden.right(10)

aiden.penup()
aiden.color('white')

for i in range(36):
    aiden.forward(220)
    aiden.pendown()
    aiden.circle(5)
    aiden.penup()
    aiden.backward(220)
    aiden.right(10)

aiden.hideturtle()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 20
#      16
#      17 for i in range(36):
#      18     aiden.forward(220)
#      19     aiden.pendown()
# ---> 20     aiden.circle(5)
#      21     aiden.penup()
#      22     aiden.backward(220)
#      23     aiden.right(10)
#
# File ~/miniconda3/envs/agentic/lib/python3.13/turtle.py:2006, in TNavigator.circle(self, radius, extent, steps)
#    2004     self.speed(speed)
#    2005     self._go(l)
# -> 2006     self.speed(0)
#    2007     self._rotate(w)
#    2008 self._rotate(-w2)
#
# File ~/miniconda3/envs/agentic/lib/python3.13/turtle.py:2188, in TPen.speed(self, speed)
#    2186 else:
#    2187     speed = 0
# -> 2188 self.pen(speed=speed)
#
# File ~/miniconda3/envs/agentic/lib/python3.13/turtle.py:2489, in TPen.pen(self, pen, **pendict)
#    2486     sa, ca = math.sin(self._tilt), math.cos(self._tilt)
#    2487     self._shapetrafo = ( scx*ca, scy*(shf*ca + sa),
#    2488                         -scx*sa, scy*(ca - shf*sa))
# -> 2489 self._update()
#
# File ~/miniconda3/envs/agentic/lib/python3.13/turtle.py:2693, in RawTurtle._update(self)
#    2691     self._drawturtle()
#    2692     screen._update()                  # TurtleScreenBase
# -> 2693     screen._delay(screen._delayvalue) # TurtleScreenBase
#    2694 else:
#    2695     self._update_data()
#
# File ~/miniconda3/envs/agentic/lib/python3.13/turtle.py:559, in TurtleScreenBase._delay(self, delay)
#     557 def _delay(self, delay):
#     558     """Delay subsequent canvas actions for delay ms."""
# --> 559     self.cv.after(delay)
#
# File ~/miniconda3/envs/agentic/lib/python3.13/tkinter/__init__.py:857, in Misc.after(self, ms, func, *args)
#     849 """Call function once after given time.
#     850
#     851 MS specifies the time in milliseconds. FUNC gives the
#     852 function which shall be called. Additional parameters
#     853 are given as parameters to the function call.  Return
#     854 identifier to cancel scheduling with after_cancel."""
#     855 if func is None:
#     856     # I'd rather use time.sleep(ms*0.001)
# --> 857     self.tk.call('after', ms)
#     858     return None
#     859 else:
#
# KeyboardInterrupt:

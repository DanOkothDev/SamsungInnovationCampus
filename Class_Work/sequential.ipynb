# %%
def do_experiment(floor, breaking):
    return floor >= breaking

def find_highest_safe_floor(height, breaking):

    for n in range(1, height + 1):
        
        if do_experiment(n, breaking):
            return n -1

    return height

# %%
from random import randint

height = int(input("Input the number of floors: "))

breaking = randint(1, height)

floor = find_highest_safe_floor(height, breaking)

print(f"Your egg will safe till the {floor}-th floor.")
# Out:
# Your egg will safe till the 63-th floor.

# %%
def seq_search(nums, x):
    for i in range(len(nums)):
        if x == nums[i]:
            return i
        

    return -1

# %%
S = [1, 2, 3, 4, 5, 6, 7, 8]
x = 10
pos = seq_search(S, x)

if pos == -1:
    print(f"{x} is not in S")
else:
    print(f"In S, {x} is at position {pos}")
# Out:
# 10 is not in S

# %%
def find_two(nums):
    x = y = 0
    for i in range(1, len(nums)):
        if nums[x] < nums[i]:
            x = i
        elif nums[y] > nums[i]:
            y = i
    return x, y

nums = [11, 37, 45, 26, 59, 28, 17, 53]
i, j = find_two(nums)

print(nums[i], nums[j])
# Out:
# 59 11

# %%
def word_count(a, x: str):
    count = 0
    value = x

    for i in range(len(a)):
        if value == a[i]:
            count += 1

    return count

S = list(input("Input a sentence: ").split())
x = input("Input a word to search: ")

count = word_count(S, x)
print(f"In S, {x} appeared in {count} times.")
# Out:
# In S, the appeared in 3 times.

# %%
def bin_search(nums, X):
    low, high = 0, len(nums) -1
    while low <= high:
        mid = (low + high) // 2
        if nums[mid] == X:
            return mid
        elif nums[mid] > X:
            high = mid - 1

        else:
            low = mid + 1

    return -1


S = [11, 17, 26, 28 , 37, 45, 53, 59]
x = int(input("Input the number to search: "))

pos = bin_search(S, x)
print(f"In S, {x} is at position {pos}")
# Out:
# In S, 53 is at position 6

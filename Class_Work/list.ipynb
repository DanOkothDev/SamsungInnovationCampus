# %%
my_list = []

my_tuple = ("Oranges", "Mangoes")
my_list.extend(my_tuple)
my_list.pop()
print(my_list)

# %%
fruits = ['orange', 'apple', 'pear', 'banana', 'kiwi', 'apple', 'banana']
fruits.count("apple")

# %%
fruits.sort(reverse=False)
print(fruits)

# %%
from collections import deque

queue = deque([2, 3, 4, 5])
queue.append(6)
queue.append(7)
queue.popleft()
print(queue)

# %%
my_tuple = ()
print(help(my_tuple))

# %%
person1 = ["David Doe", 20, 1, 150.0, 100.0]
person2 = ["John Smith", 25, 1, 170.0, 70.0]
person3 = ["Jane Carter", 22, 0, 169.0, 68.0]
person4 = ["Peter Kelly", 40, 1, 150.0, 50.0]

person_list = person1 + person2 + person3 + person4
print(person_list)

n_persons = int(len(person_list) / 5)
age_sum = 0.0
for age in person_list[1::6]:
    age_sum += age
average_age = float(age_sum) / n_persons
print("The average age is", str(average_age))
# Out:
# ['David Doe', 20, 1, 150.0, 100.0, 'John Smith', 25, 1, 170.0, 70.0, 'Jane Carter', 22, 0, 169.0, 68.0, 'Peter Kelly', 40, 1, 150.0, 50.0]
# The average age is 60.0

# %%
my_list = [x ** 2 for x in range(40)]

print(my_list)

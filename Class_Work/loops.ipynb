# %%
for i in range(0, 20, 2):
    print(i, end=" ")

# %%
my_list = [1, 2, 3, 4, 5, 6, 7, 8, 9]
print(my_list[:-2])
print(my_list[::-1])
print(my_list[1::-1])

# %%
prime_list = [2, 3, 5, 7]
print(f"1st element of prime_list: {prime_list[0]}")

# %%
list1 = [3, 5, 7]
list2 = [2, 3, 4, 5 ,6]

for i in list1:
    for j in list2:
        print(f"{i} * {j} = {i * j}")

# %%
for i, j in zip(list1, list2):
    print(f"{i * j}")

# %%
my_dict = {"Name":"Doe", "Age": 30, "GPA": 3.4, "isStudent": True}
my_dict.update({"Name": "John"})
for key, value in my_dict.items():
    print(key, value, end=" ")

# %%
import json

student = {"Name": "Doe", "Age": 20, "gpa": 30}

with open("stud.json", "w") as f:
    data = json.dump(student, f, indent=2)
    

with open("stud.json", "r") as f:
    data = json.load(f)
    print(data)

# %%
s_list = ["abcFGDDJD", "bcd", "bcdefg", "abba", "cddc", "opq"]

for i, j in enumerate(s_list):
    shortest = s_list[0]
    if len(s_list[0]) <= len(s_list[i]):
        shortest = s_list[0]
    else:
        s_list[i]

print(f"The shortest string: {shortest}")

# %%
from functools import reduce

s_list = ["abc", "bcd", "bcdefg", "abba", "cddc", "opq"]
#longest = reduce(lambda s : s_list[i] if s_list[0] >= s_list[i] else s_list[0], s_list)
#print(longest)


for i, j in enumerate(s_list):
    longest = s_list[0]
    if len(s_list[0]) <= len(s_list[i]):
        longest = s_list[i]
        print(len(longest))
    

# print(f"The longest string: {longest}")

# %%
import json
data = '{"name" : "david doe", "age": 25, "hobby": ["basketball"], "family" : {"father": "john doe", "mother": "marry doe"}, "married": true}'

json_data = json.loads(data)
print(type(json_data))

print(json_data["family"])
print(json_data)

# %%
import json
class ComplexEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, complex):
            return [obj.real, obj.imag]
        # Let the base class default method raise the TypeError
        return super().default(obj)

json.dumps(2 + 1j, cls=ComplexEncoder)

ComplexEncoder().encode(2 + 1j)

list(ComplexEncoder().iterencode(2 + 1j))

# %%
capital_dic = {"Korea": "seoul", "China": "Beijing", "USA": "Washington DC"}
print(capital_dic["China"])

# %%
for i in capital_dic:
    print(f"The capital of {i} is {capital_dic[i]}")

# %%
s_list = ["abc", "bcd", "bcdefg", "abba", "cddc", "opq"]

shortest = s_list[0]  


for s in s_list:
    if len(s) < len(shortest):
        s_list.sort(key=len)
        shortest = s
    
print(f"The shortest string: {shortest}")

# %%
longest = s_list[0]

for s in s_list:
    if len(s) > len(longest):
        longest = s
print(f"The longest string: {longest}")

# %%
mylist = [2, 3, 4, 5, 6, 7, 8, 9]

print(mylist[::-1])

# %%
s_list.sort(key=len)

shortests = []
min_length = s_list[0]

for i in s_list:
    if len(i) == len(min_length):
        shortests.append(i)
    else:
        break


print(f"The shortest is: {shortests}")

# %%
fruits_dic = {"apple": 6000, "melon": 3000, "banana": 5000, "orange": 4000}

print(fruits_dic.keys())
print("mango" in fruits_dic)
print("apple" in fruits_dic)

# %%
person_dic = {"Last name" : "Doe", "First name": "John", "Campany": "Samsung"}
print(person_dic.items())
